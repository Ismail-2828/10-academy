# %%
import numpy as np
import pandas as pd

# %%
traffic_data = pd.read_csv(r"C:\Users\ismai\chalenge\10X_Files\traffic_data\traffic.csv")
raw_data = pd.read_csv(r"C:\Users\ismai\chalenge\10X_Files\raw_data\data.csv")
rating_data = pd.read_csv(r"C:\Users\ismai\chalenge\10X_Files\data.csv\rating.csv")

# %%
rating_data.columns
# Out:
# Index(['article_id', 'source_id', 'source_name', 'author', 'title',
#        'description', 'url', 'url_to_image', 'published_at', 'content',
#        'category', 'article', 'title_sentiment', 'country'],
#       dtype='object')

# %%
raw_data.columns
# Out:
# Index(['article_id', 'source_id', 'source_name', 'author', 'title',
#        'description', 'url', 'url_to_image', 'published_at', 'content',
#        'category', 'full_content'],
#       dtype='object')

# %%
traffic_data.tail()
# Out:
#         GlobalRank  TldRank                  Domain  TLD  RefSubNets  RefIPs  \
# 999995      999996   485324              kireie.com  com         222     280
# 999996      999997   485325             mt-lock.com  com         222     280
# 999997      999998   485326           pinkwater.com  com         222     280
# 999998      999999   485327          soderhomes.com  com         222     280
# 999999     1000000   485328  toyotamusicfactory.com  com         222     280
#
#                     IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  \
# 999995              kireie.com     com              -1           -1
# 999996             mt-lock.com     com          952633       461429
# 999997           pinkwater.com     com              -1           -1
# 999998          soderhomes.com     com              -1           -1
# 999999  toyotamusicfactory.com     com          973201       471949
#
#         PrevRefSubNets  PrevRefIPs
# 999995              -1          -1
# ...

# %%
traffic_data.columns
# Out:
# Index(['GlobalRank', 'TldRank', 'Domain', 'TLD', 'RefSubNets', 'RefIPs',
#        'IDN_Domain', 'IDN_TLD', 'PrevGlobalRank', 'PrevTldRank',
#        'PrevRefSubNets', 'PrevRefIPs'],
#       dtype='object')

# %%
#Question 2
sorted_traffic_data = traffic_data.sort_values(by='GlobalRank', ascending=True)
top_traffic_websites = sorted_traffic_data.head(10)
print(top_traffic_websites[['Domain', 'GlobalRank']])
# Out:
#                  Domain  GlobalRank
# 0            google.com           1
# 1          facebook.com           2
# 2           youtube.com           3
# 3           twitter.com           4
# 4         instagram.com           5
# 5          linkedin.com           6
# 6             apple.com           7
# 7         microsoft.com           8
# 8  googletagmanager.com           9
# 9         wikipedia.org          10

# %%
raw_data.columns
# Out:
# Index(['article_id', 'source_id', 'source_name', 'author', 'title',
#        'description', 'url', 'url_to_image', 'published_at', 'content',
#        'category', 'full_content'],
#       dtype='object')

# %%
rating_data.head()
# Out:
#    article_id source_id     source_name  \
# 0       81664       NaN          Forbes
# 1       81667       NaN             CNA
# 2       81694      time            Time
# 3       81695       NaN        Phys.Org
# 4       81703       NaN  Digital Trends
#
#                                               author  \
# 0  Elizabeth Brownfield, Contributor, \n Elizabet...
# 1                                                NaN
# 2                              Christina Larson / AP
# 3                                       Sara Schmidt
# 4                                       Jason Struss
#
#                                                title  \
# 0  superstar chef yannick alléno brings refined f...
# 1  nice claim top spot in ligue 1 with late win a...
# 2  amphibians are the world’s most vulnerable spe...
# 3              image: rusty red waters in madagascar
# 4  everything leaving max (formerly hbo max) in n...
#
#                                          description  \
# ...

# %%
#Question 1
largest_website = rating_data['source_name'].value_counts().idxmax()
print(f"The website with the largest count of news articles is '{largest_website}' ")
# Out:
# The website with the largest count of news articles is 'ETF Daily News'

# %%
#Question 7
sentiment_counts = rating_data.groupby(['source_name', 'title_sentiment']).size().unstack(fill_value=0)
sentiment_counts['dominant_sentiment'] = sentiment_counts.idxmax(axis=1)
print(sentiment_counts)
# Out:
# title_sentiment               Negative  Neutral  Positive dominant_sentiment
# source_name
# ABC News                           726     1193       139            Neutral
# Al Jazeera English                 706      927        31            Neutral
# AllAfrica - Top Africa News          8       12         0            Neutral
# Android Central                     38      212       272           Positive
# BBC News                           854     1185        74            Neutral
# Boing Boing                        250      293       170            Neutral
# Business Insider                   890      907       237            Neutral
# CNA                                126      462        86            Neutral
# CNN                                102      142        23            Neutral
# Deadline                            84      794        54            Neutral
# Digital Trends                      43      335       406           Positive
# ...

# %%
sentiment_counts['dominant_sentiment'].value_counts()
# Out:
# Neutral     27
# Positive     2
# Name: dominant_sentiment, dtype: int64

# %%
rating_data.iloc[2]["content"]
# Out:
# 'The worlds frogs, salamanders, newts and other amphibians remain in serious trouble.\nA new global assessment has found that 41% of amphibian species that scientists have studied are threatened with … [+2579 chars]'

# %%
#Question 4
import re
rating_data['description'] = rating_data['description'].str.upper()
rating_data['country'] = rating_data['description'].str.extract(r'\b(Africa|US|China|EU|Russia|Ukraine|Middle East)\b', flags=re.IGNORECASE)
country_media_orgs = rating_data.groupby('country')['source_name'].nunique()


print("Countries with the highest number of news media organizations:")
print(country_media_orgs.nlargest(10))
print()
# Out:
# Countries with the highest number of news media organizations:
# country
# US             28
# CHINA          25
# EU             23
# AFRICA         22
# MIDDLE EAST    21
# RUSSIA         21
# UKRAINE        20
# Name: source_name, dtype: int64

# %%
rating_data.head()
# Out:
#    article_id source_id     source_name  \
# 0       81664       NaN          Forbes
# 1       81667       NaN             CNA
# 2       81694      time            Time
# 3       81695       NaN        Phys.Org
# 4       81703       NaN  Digital Trends
#
#                                               author  \
# 0  Elizabeth Brownfield, Contributor, \n Elizabet...
# 1                                                NaN
# 2                              Christina Larson / AP
# 3                                       Sara Schmidt
# 4                                       Jason Struss
#
#                                                title  \
# 0  superstar chef yannick alléno brings refined f...
# 1  nice claim top spot in ligue 1 with late win a...
# 2  amphibians are the world’s most vulnerable spe...
# 3              image: rusty red waters in madagascar
# 4  everything leaving max (formerly hbo max) in n...
#
#                                          description  \
# ...

# %%
rating_data.columns
# Out:
# Index(['article_id', 'source_id', 'source_name', 'author', 'title',
#        'description', 'url', 'url_to_image', 'published_at', 'content',
#        'category', 'article', 'title_sentiment', 'country'],
#       dtype='object')

# %%
rating_data.iloc[0]["description"]
# Out:
# 'Now open in Mayfair at Four Seasons Hotel London at Park Lane, the restaurant is the Michelin-starred chef’s London debut.'

# %%
import pandas as pd 
domain_data = pd.read_csv(r"C:\Users\ismai\Downloads\domains_location.csv")
domain_data.head(20)
# Out:
#     SourceCommonName location        Country
# 0         00221.info       SG        Senegal
# 1          01net.com       FR         France
# 2           01net.it       IT          Italy
# 3        0223.com.ar       AR      Argentina
# 4       022china.com       CH          China
# 5          02blog.it       IT          Italy
# 6          02elf.net       GM        Germany
# 7             032.ua       UP        Ukraine
# 8            0362.ua       UP        Ukraine
# 9            0372.ua       UP        Ukraine
# 10            048.ua       UP        Ukraine
# 11           0542.ua       UP        Ukraine
# 12     055firenze.it       IT          Italy
# 13           0564.ua       UP        Ukraine
# 14            057.ua       UP        Ukraine
# 15            061.ua       UP        Ukraine
# 16  06880danwoog.com       US  United States
# 17          07kbr.ru       RS         Russia
# 18           0lf.net       EG          Egypt
# 19           1.zt.ua       UP        Ukraine

# %%
#QUESTION 3
domain_data["Country"].value_counts().head(1)
# Out:
# United States    14111
# Name: Country, dtype: int64

# %%
domain_data.columns
# Out:
# Index(['SourceCommonName', 'location', 'Country'], dtype='object')

# %%
#Beginning of question 5
domain_data["Country"].unique()
# Out:
# array(['Senegal', 'France', 'Italy', 'Argentina', 'China', 'Germany',
#        'Ukraine', 'United States', 'Russia', 'Egypt', 'India', 'Taiwan',
#        'United Kingdom', 'Canada', 'South Africa', 'Greece',
#        'Netherlands', 'Chile', 'Iran', 'Cuba', 'Lithuania', 'Hungary',
#        'Uruguay', 'Brazil', 'Switzerland', 'Armenia', 'Indonesia',
#        'Azerbaijan', 'Bangladesh', 'Georgia', 'Tuvalu', 'Venezuela',
#        'Spain', 'Latvia', 'Cameroon', 'Mexico', 'United Arab Emirates',
#        'Portugal', 'Kuwait', 'Bulgaria', 'Vietnam', 'Turkey', 'Benin',
#        'Mauritius', 'Slovak Republic', 'Kyrgyzstan', 'Poland', 'Aruba',
#        'Syria', 'Croatia', 'Bosnia-Herzegovina', 'Serbia', 'Slovenia',
#        'Macedonia', 'Australia', 'Ethiopia', 'Israel', 'Nigeria',
#        'Kazakhstan', 'Japan', 'Keeling Islands', 'North Korea',
#        'Saudi Arabia', 'New Zealand', 'Romania', 'Colombia', 'Austria',
#        'Belarus', 'Czech Republic', 'Thailand', 'Luxembourg', 'Norway',
# ...

# %%
# import pandas as pd

# def extract_continent_countries(unique_countries):
#     africa_countries = ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 
#                         'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo', "Cote d'Ivoire", 
#                         'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 
#                         'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 
#                         'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 
#                         'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 
#                         'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 
#                         'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe']
    
#     eu_countries = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 
#                     'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 
#                     'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 
#                     'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden']
    
#     middle_east_countries = ['Bahrain', 'Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman', 
#                              'Palestine', 'Qatar', 'Saudi Arabia', 'Syria', 'Turkey', 'United Arab Emirates', 'Yemen']
    
#     africa = [country for country in unique_countries if country in africa_countries]
#     eu = [country for country in unique_countries if country in eu_countries]
#     middle_east = [country for country in unique_countries if country in middle_east_countries]
    
#     return africa, eu, middle_east

# unique_countries = domain_data['Country'].unique()

# africa_countries, eu_countries, middle_east_countries = extract_continent_countries(unique_countries)


# continent_mapping = {
#     'Africa': africa_countries,
#     'EU': eu_countries,
#     'Middle East': middle_east_countries,
#     'US': ['United State'],
#     'China': ['China'],
#     'Russia': ['Russia'],
#     'Ukraine': ['Ukraine'],
# }

# def map_continent(country):
#     for continent, countries in continent_mapping.items():
#         if country in countries:
#             return continent
#     return 'Other'

# domain_data['continent'] = domain_data['Country'].apply(map_continent)


# continent_counts = domain_data.groupby('continent')['SourceCommonName'].count()
# print(continent_counts)
# Out:
# continent
# Africa          1546
# China            780
# EU              8063
# Middle East     1832
# Other          24060
# Russia          1024
# Ukraine          497
# Name: SourceCommonName, dtype: int64

# %%
#Question 5
import pandas as pd

def extract_continent_countries(unique_countries):
    africa_countries = ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 
                        'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo', "Cote d'Ivoire", 
                        'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 
                        'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 
                        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 
                        'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 
                        'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 
                        'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe']
    
    eu_countries = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 
                    'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 
                    'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 
                    'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden']
    
    middle_east_countries = ['Bahrain', 'Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman', 
                             'Palestine', 'Qatar', 'Saudi Arabia', 'Syria', 'Turkey', 'United Arab Emirates', 'Yemen']
    
    africa = [country for country in unique_countries if country in africa_countries]
    eu = [country for country in unique_countries if country in eu_countries]
    middle_east = [country for country in unique_countries if country in middle_east_countries]
    
    return africa, eu, middle_east

unique_countries = domain_data['Country'].unique()

africa_countries, eu_countries, middle_east_countries = extract_continent_countries(unique_countries)


continent_mapping = {
    'Africa': africa_countries,
    'EU': eu_countries,
    'Middle East': middle_east_countries,
    'US': ['United States'],
    'China': ['China'],
    'Russia': ['Russia'],
    'Ukraine': ['Ukraine'],
}

def map_continent(country):
    for continent, countries in continent_mapping.items():
        if country in countries:
            return continent
    return 'Other'

domain_data['continent'] = domain_data['Country'].apply(map_continent)
continent_websites = domain_data.groupby('continent')['SourceCommonName'].apply(list)

for continent, websites in continent_websites.items():
    print(continent, "Websites:", websites)
# Out:
# Africa Websites: ['00221.info', '0lf.net', '1049.fm', '11news.xyz', '12news.xyz', '14news.xyz', '15news.xyz', '237online.com', '24.com.eg', '24haubenin.info', '24heuresinfo.com', '24hoursnews.net', '2merkato.com', '2oceansviberadio.com', '360nobs.com', '364news.com', '3ajlnews.com', '3alakefak.net', '3amnews.com', '3d-car-shows.com', '3misr.com', '3robanews.com', '3sola.net', '3yonnews.com', '411board.com', '4gafrica.co.za', '4mnews.com', '5stardurban.co.za', '6000.co.za', '6april.org', '702.co.za', '73com.net', '7daynews.net', '7oria.net', '9ames.net', 'aadanyabaal.com', 'abamako.com', 'abugidainfo.com', 'abujavoice.com', 'abusidiqu.com', 'acap-cf.info', 'accu.or.ug', 'acdhrs.org', 'achpr.org', 'acotonou.com', 'acrosnews.com', 'actu-monde.com', 'actuniger.com', 'actusen.com', 'adakar.com', 'addisfortune.net', 'addistar.com', 'adiac-congo.com', 'advar.net', 'advar.ps', 'aeronautique.ma', 'afaq-arabia.com', 'afkinsider.com', 'afribiz.info', 'afribone.com', 'africa-ontherise.com', 'afr
# ...
